# %% [markdown]
# <a href="https://colab.research.google.com/github/harihargana/data-harvesting-warehousing/blob/main/phonepe_pulse.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install gitpython

# %%
import git
git.Git("https://github.com/PhonePe/pulse/tree/master/data").clone("https://github.com/harihargana/phonepe/mainline.git")

# %%
'''Test storing in git hub'''
# Out:
# 'Test storing in git hub'

# %%
'''
  Data Exploration
'''

# Sample transaction at country level
{
  "success": true,
  "code": "SUCCESS",
  "data": {
    "from": 1704047400000,
    "to": 1711564200000,
    "transactionData": [
      {
        "name": "Merchant payments",
        "paymentInstruments": [
          {
            "type": "TOTAL",
            "count": 12520741960,
            "amount": 5962442621632
          }
        ]
      },
      {
        "name": "Peer-to-peer payments",
        "paymentInstruments": [
          {
            "type": "TOTAL",
            "count": 7335480797,
            "amount": 22327480157794
          }
        ]
      },
      {
        "name": "Recharge & bill payments",
        "paymentInstruments": [
          {
            "type": "TOTAL",
            "count": 1365204965,
            "amount": 1150335013422
          }
        ]
      },
      {
        "name": "Financial Services",
        "paymentInstruments": [
          {
            "type": "TOTAL",
            "count": 7419656,
            "amount": 11806228360
          }
        ]
      },
      {
        "name": "Others",
        "paymentInstruments": [
          {
            "type": "TOTAL",
            "count": 8290191,
            "amount": 6518078355
          }
        ]
      }
    ]
  },
  "responseTimestamp": 1714727583089
}

# %%
{
  "success": true,
  "code": "SUCCESS",
  "data": {
    "hoverDataList": [
      {
        "name": "puducherry",
        "metric": [
          {
            "type": "TOTAL",
            "count": 13446950,
            "amount": 17386481977
          }
        ]
      },
      {
        "name": "tamil nadu",
        "metric": [
          {
            "type": "TOTAL",
            "count": 640327197,
            "amount": 913861111062
          }
        ]
      },
      {
        "name": "uttar pradesh",
        "metric": [
          {
            "type": "TOTAL",
            "count": 1785296948,
            "amount": 2477543106639
          }
        ]
      },
      {
        "name": "madhya pradesh",
        "metric": [
          {
            "type": "TOTAL",
            "count": 1286156614,
            "amount": 1625420229864
          }
        ]
      },
      {
        "name": "andhra pradesh",
        "metric": [
          {
            "type": "TOTAL",
            "count": 1755428485,
            "amount": 3012725669749
          }
        ]
      },
      {
        "name": "tripura",
        "metric": [
          {
            "type": "TOTAL",
            "count": 11042639,
            "amount": 17752189374
          }
        ]
      },
      {
        "name": "lakshadweep",
        "metric": [
          {
            "type": "TOTAL",
            "count": 81176,
            "amount": 130052381
          }
        ]
      },
      {
        "name": "manipur",
        "metric": [
          {
            "type": "TOTAL",
            "count": 3845564,
            "amount": 9242973323
          }
        ]
      },
      {
        "name": "maharashtra",
        "metric": [
          {
            "type": "TOTAL",
            "count": 2835770481,
            "amount": 3372898894856
          }
        ]
      },
      {
        "name": "dadra & nagar haveli & daman & diu",
        "metric": [
          {
            "type": "TOTAL",
            "count": 21115009,
            "amount": 19519196325
          }
        ]
      },
      {
        "name": "meghalaya",
        "metric": [
          {
            "type": "TOTAL",
            "count": 8531262,
            "amount": 15629304658
          }
        ]
      },
      {
        "name": "andaman & nicobar islands",
        "metric": [
          {
            "type": "TOTAL",
            "count": 4184920,
            "amount": 6859151835
          }
        ]
      },
      {
        "name": "haryana",
        "metric": [
          {
            "type": "TOTAL",
            "count": 604293500,
            "amount": 806788219232
          }
        ]
      },
      {
        "name": "rajasthan",
        "metric": [
          {
            "type": "TOTAL",
            "count": 1599474007,
            "amount": 2350500173790
          }
        ]
      },
      {
        "name": "ladakh",
        "metric": [
          {
            "type": "TOTAL",
            "count": 2987101,
            "amount": 6085390661
          }
        ]
      },
      {
        "name": "punjab",
        "metric": [
          {
            "type": "TOTAL",
            "count": 142537179,
            "amount": 223303420322
          }
        ]
      },
      {
        "name": "assam",
        "metric": [
          {
            "type": "TOTAL",
            "count": 221525056,
            "amount": 321183906030
          }
        ]
      },
      {
        "name": "jharkhand",
        "metric": [
          {
            "type": "TOTAL",
            "count": 426759095,
            "amount": 559720237073
          }
        ]
      },
      {
        "name": "odisha",
        "metric": [
          {
            "type": "TOTAL",
            "count": 864178452,
            "amount": 1156388722536
          }
        ]
      },
      {
        "name": "bihar",
        "metric": [
          {
            "type": "TOTAL",
            "count": 1078734783,
            "amount": 1637736864896
          }
        ]
      },
      {
        "name": "kerala",
        "metric": [
          {
            "type": "TOTAL",
            "count": 181463966,
            "amount": 227077974738
          }
        ]
      },
      {
        "name": "karnataka",
        "metric": [
          {
            "type": "TOTAL",
            "count": 2796439155,
            "amount": 3485248654506
          }
        ]
      },
      {
        "name": "chandigarh",
        "metric": [
          {
            "type": "TOTAL",
            "count": 13155173,
            "amount": 15842176181
          }
        ]
      },
      {
        "name": "telangana",
        "metric": [
          {
            "type": "TOTAL",
            "count": 2179385307,
            "amount": 3203769301073
          }
        ]
      },
      {
        "name": "himachal pradesh",
        "metric": [
          {
            "type": "TOTAL",
            "count": 39520561,
            "amount": 47884231339
          }
        ]
      },
      {
        "name": "west bengal",
        "metric": [
          {
            "type": "TOTAL",
            "count": 836408587,
            "amount": 1422025506833
          }
        ]
      },
      {
        "name": "gujarat",
        "metric": [
          {
            "type": "TOTAL",
            "count": 606576671,
            "amount": 871619464924
          }
        ]
      },
      {
        "name": "sikkim",
        "metric": [
          {
            "type": "TOTAL",
            "count": 5820146,
            "amount": 9455721523
          }
        ]
      },
      {
        "name": "nagaland",
        "metric": [
          {
            "type": "TOTAL",
            "count": 4258924,
            "amount": 10044915308
          }
        ]
      },
      {
        "name": "mizoram",
        "metric": [
          {
            "type": "TOTAL",
            "count": 1627016,
            "amount": 3630096730
          }
        ]
      },
      {
        "name": "chhattisgarh",
        "metric": [
          {
            "type": "TOTAL",
            "count": 366176684,
            "amount": 463009809901
          }
        ]
      },
      {
        "name": "jammu & kashmir",
        "metric": [
          {
            "type": "TOTAL",
            "count": 75116355,
            "amount": 93960928941
          }
        ]
      },
      {
        "name": "goa",
        "metric": [
          {
            "type": "TOTAL",
            "count": 35013987,
            "amount": 45351900260
          }
        ]
      },
      {
        "name": "arunachal pradesh",
        "metric": [
          {
            "type": "TOTAL",
            "count": 16406414,
            "amount": 26047044476
          }
        ]
      },
      {
        "name": "delhi",
        "metric": [
          {
            "type": "TOTAL",
            "count": 650734058,
            "amount": 832514031113
          }
        ]
      },
      {
        "name": "uttarakhand",
        "metric": [
          {
            "type": "TOTAL",
            "count": 123234577,
            "amount": 150276835263
          }
        ]
      }
    ]
  },
  "responseTimestamp": 1714727583490
}

# %%
{
  "success": true,
  "code": "SUCCESS",
  "data": {
    "aggregated": {
      "registeredUsers": 46877867,
      "appOpens": 0
    },
    "usersByDevice": [
      {
        "brand": "Xiaomi",
        "count": 11926334,
        "percentage": 0.25441289809538475
      },
      {
        "brand": "Samsung",
        "count": 9609401,
        "percentage": 0.204988017052909
      },
      {
        "brand": "Vivo",
        "count": 5894293,
        "percentage": 0.1257372269092363
      },
      {
        "brand": "Oppo",
        "count": 4479351,
        "percentage": 0.09555364368434255
      },
      {
        "brand": "Realme",
        "count": 2376866,
        "percentage": 0.05070337351313361
      },
      {
        "brand": "Apple",
        "count": 1825153,
        "percentage": 0.03893421601285741
      },
      {
        "brand": "Motorola",
        "count": 1593250,
        "percentage": 0.033987254582210406
      },
      {
        "brand": "OnePlus",
        "count": 1536418,
        "percentage": 0.03277491273227086
      },
      {
        "brand": "Lenovo",
        "count": 1246507,
        "percentage": 0.026590522986039446
      },
      {
        "brand": "Huawei",
        "count": 808774,
        "percentage": 0.01725279010668297
      },
      {
        "brand": "Others",
        "count": 5581520,
        "percentage": 0.1190651443249327
      }
    ]
  },
  "responseTimestamp": 1630501482414
}
